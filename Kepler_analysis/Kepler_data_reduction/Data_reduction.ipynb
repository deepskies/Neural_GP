# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from tqdm import tqdm

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd

import torch
device = torch.device('cpu')


#JAX
import jax
import jax.numpy as jnp

from jax_cosmo.scipy import interpolate as jax_interpolate

# Probably should specify in the outer script, not the inner modules
from jax.config import config
config.update("jax_enable_x64", True)
config.update("jax_debug_nans", True)

# for Matern kernel with Modified Bessel of the 2nd kind (tfp>=0.17.0-dev20220322)
import tensorflow_probability as tfp


#CPUs parallelization
import multiprocessing
max_thread_numbers=multiprocessing.cpu_count()
import os
os.environ["XLA_FLAGS"] = "--xla_force_host_platform_device_count=%d"%(max_thread_numbers)


# %matplotlib inline
from pyke import kepcotrend,kepdetrend,kepmask
# %matplotlib inline

fig = plt.figure()
#plt.plot()
mpl.style.use('default')
rcParams = {
    "lines.color": "white",
    "patch.edgecolor": "white",
    "text.color": "black",
    "axes.facecolor": "lightgray",
    "axes.edgecolor": "lightgray",
    "axes.labelcolor": "white",
    "xtick.color": "white",
    "ytick.color": "white",
    "grid.color": "lightgray",
    "figure.facecolor": "black",
    "figure.edgecolor": "black",
    "savefig.facecolor": "black",
    "savefig.edgecolor": "black",
    "legend.facecolor":'lightgray',
    "legend.edgecolor":'black',
    'axes.titlecolor': 'white'}

def set_style():
    global fig
    mpl.style.use('default')
    plt.rcParams.update(rcParams)
    fig.patch.set_alpha(0)

FS = 18 # fontsize


import warnings
warnings.simplefilter("ignore", UserWarning)

def to_date(time_array,offset_date='2000-01-01T00:00:00'):
    return np.array([pd.Timedelta(x,'days').round('d')+pd.Timestamp(offset_date) for x in time_array])

# %% [markdown]
# # Download Kepler Light curves

# %%
# !ls
# Out:
# CBVs                    Overview.ipynb          light_curves_CBV_corr
# Data_analysis.ipynb     Power_spectra.ipynb     light_curves_CBV_corr_1
# Data_analysis_old.ipynb Spectra.ipynb           light_curves_CBV_corr_2
# Data_reduction.ipynb    kepcotrend.log          reduced_light_curves
# MCMC_chains             light_curves

# %%
# !cd light_curves

# %%
download_command = 'wget -r -np -nH -q -erobots=off -A llc.fits -P light_curves/ --cut-dirs=4 https://archive.stsci.edu/missions/kepler/lightcurves/'

# %%
q = np.array(os.listdir('light_curves'))
q = np.sort(q)
q
# Out:
# array(['.DS_Store', '002694186', '002837332', '003347632', '005781475',
#        '006932990', '007175757', '007523720', '007610713', '008946433',
#        '009145961', '009215110', '009650712', '010645722', '010798894',
#        '010841941', '011413175', '011606854', '012010193', '012158940',
#        '012208602', '012401487'], dtype='<U9')

# %%
'''kids_to_download = [7523720,7610713,8946433,9145961,9650712]
for kid in kids_to_download:
    os.system(download_command+'00'+str(kid)[:2]+'/00'+str(kid)+'/')'''

# %%
'''kids_to_download = [10645722,10798894,10841941,11413175,11606854]
for kid in kids_to_download:
    os.system(download_command+'0'+str(kid)[:3]+'/0'+str(kid)+'/')'''

# %%
'''kids_to_download = [12208602]
for kid in kids_to_download:
    os.system(download_command+'0'+str(kid)[:3]+'/0'+str(kid)+'/')'''

# %% [markdown]
# # Detrending

# %%
# !pwd
# Out:
# /Users/egorssed/Desktop/Science/sbi-lensed-qso/Physics paper/datasets/Kepler

# %%
from astropy.io import fits
from pathlib import Path

Datafolder = './light_curves/'
CBVs_path = './CBVs/'
names = np.array(os.listdir(Datafolder))
names = names[names != '.DS_Store']
names = np.sort(names)

CBVs_names =  np.array(os.listdir(CBVs_path))
CBVs_names = CBVs_names[CBVs_names != '.DS_Store']
CBVs_names = np.sort(CBVs_names)

# %%
kepcotrend??

# %%
from copy import deepcopy
def detrend_object(object_index,listbv = '1 2',verbose=False,iterate=False,sigma=5,fitmethod='llsq',fitpower=1):
    object_path = (Datafolder)+str(names[object_index])+'/'
    for index in range(len(os.listdir(object_path))):
        detrend_curve(object_path,index,listbv,verbose,iterate,sigma,fitmethod,fitpower)

def detrend_curve(object_path,curve_index,listbv = '1 2',verbose=False,iterate=False,sigma=5,fitmethod='llsq',fitpower=1):
    curve_path = object_path+'/'+os.listdir(object_path)[curve_index]

    new_path = './light_curves_CBV_corr_'+str(len(listbv)//2 + 1)+'/'+str(names[object_index])+'/'
    Path(new_path).mkdir(parents=True,exist_ok=True)
    new_curve_path = new_path+os.listdir(object_path)[curve_index]


    with fits.open(curve_path) as hdul:
        quarter = hdul[0].header['QUARTER']

    CBV_path = CBVs_path+str(CBVs_names[quarter])
    kepcotrend(curve_path,CBV_path,listbv,outfile=new_curve_path,
               overwrite=True,verbose=verbose,iterate=iterate,sigma=sigma,fitmethod=fitmethod,fitpower=fitpower)

from astropy.io import fits

def fetch_light_curve(index,listbv = '1 2'):

    new_Datafolder = './light_curves_CBV_corr_'+str(len(listbv)//2 + 1)+'/'
    names = np.array(os.listdir(new_Datafolder))
    names = names[names != '.DS_Store']
    names = np.sort(names)

    filepath = (new_Datafolder)+str(names[index])


    dfs = []
    for i,curvename in enumerate(os.listdir(filepath)):
        path = filepath+'/'+curvename
        with fits.open(path) as hdul:

            #dataframe = pd.DataFrame(hdul[1].data)[['TIME','CADENCENO','CBVSAP_FLUX','SAP_FLUX','SAP_FLUX_ERR','SAP_BKG','SAP_BKG_ERR','PDCSAP_FLUX','PDCSAP_FLUX_ERR','SAP_QUALITY']]
            dataframe = pd.DataFrame(hdul[1].data)
            #downlinks_idx = np.where(np.isin(dataframe['SAP_QUALITY'],[98312,32768]))[0]
            binary_quality = np.vectorize(lambda x: np.binary_repr(x,width=21))(dataframe['SAP_QUALITY'])
            # bit 4 is "spacecraft is in earth point", so the thermal recovery period is expected
            downlinks_idx = np.where([(x[-4]=='1') or (x==np.binary_repr(98306,width=21)) for x in binary_quality])[0]

            thermal_recovery_mask = ~((np.arange(len(dataframe))[:,None] >= downlinks_idx[None,:]) &
                          (np.arange(len(dataframe))[:,None] <= downlinks_idx[None,:] + 150)).any(1)

            dataframe['THERMAL_RECOVERY'] = thermal_recovery_mask
            mask = np.logical_and(~np.isnan(dataframe['SAP_FLUX']).values,dataframe['SAP_QUALITY']==0).values
            #mask = (dataframe['SAP_QUALITY']==0).values
            mask = np.logical_and(mask,thermal_recovery_mask)
            dataframe['MASK'] = mask
            dataframe['FILENUM'] = np.ones(len(dataframe),dtype='int')*i
            dataframe['QUARTER'] = hdul[0].header['QUARTER']

            dfs+= [dataframe]

    dfs = np.array(dfs)[np.argsort([q['QUARTER'].min() for q in dfs])]

    """
    for index in range(1,len(dfs)):
        mask1=dfs[index]['MASK'].values
        mask2=dfs[index-1]['MASK'].values

        target = 'SAP_FLUX'
        vals1 = (dfs[index][target])[mask1]
        vals2= (dfs[index-1][target])[mask2]
        shift = np.mean(vals1[:10]) - np.mean(vals2[-10:])
        dfs[index][target] -=shift

        target = 'PDCSAP_FLUX'
        vals1 = (dfs[index][target])[mask1]
        vals2= (dfs[index-1][target])[mask2]
        shift = np.mean(vals1[:10]) - np.mean(vals2[-10:])
        dfs[index][target] -=shift


        target = 'CBVSAP_FLUX'
        vals1 = (dfs[index][target])[mask1]
        vals2= (dfs[index-1][target])[mask2]
        shift = np.mean(vals1[:10]) - np.mean(vals2[-10:])
        dfs[index][target] -=shift
    """

    #df = pd.concat(dfs)
    return dfs

# %% [markdown]
# # DO all the detrending in case to case basis, so we don't have chi^2=5

# %%
for object_index in range(len(names)):
    detrend_object(object_index,iterate=False,listbv='1',fitmethod='llsq')
# Out:
# Writing output file ./light_curves_CBV_corr_1/002694186/kplr002694186-2013131215648_llc.fits...
#       -----
# reduced chi2: 291.7556988702192
# rms: 44.19781134707141
# Coefficient of CBV #1: [-0.25600395]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002694186/kplr002694186-2011177032512_llc.fits...
#       -----
# reduced chi2: 153.7583502494513
# rms: 35.66390611797244
# Coefficient of CBV #1: [0.06705369]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002694186/kplr002694186-2012004120508_llc.fits...
#       -----
# reduced chi2: 2314.995618324361
# rms: 195.36544551961052
# Coefficient of CBV #1: [-1.09933279]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002694186/kplr002694186-2012088054726_llc.fits...
#       -----
# reduced chi2: 15655.624291998192
# rms: 435.2959721203394
# Coefficient of CBV #1: [-3.22953214]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002694186/kplr002694186-2012277125453_llc.fits...
#       -----
# reduced chi2: 657.6493212829922
# rms: 79.53774813389444
# Coefficient of CBV #1: [-0.65126767]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002694186/kplr002694186-2012179063303_llc.fits...
#       -----
# reduced chi2: 252.51128946689218
# rms: 40.43004968430356
# Coefficient of CBV #1: [-0.38099137]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002694186/kplr002694186-2011073133259_llc.fits...
#       -----
# reduced chi2: 86.1569344285171
# rms: 37.030882164371754
# Coefficient of CBV #1: [0.00295496]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002694186/kplr002694186-2010355172524_llc.fits...
#       -----
# reduced chi2: 1338.741480283548
# rms: 114.0519738629686
# Coefficient of CBV #1: [-0.87975702]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002694186/kplr002694186-2011271113734_llc.fits...
#       -----
# reduced chi2: 185.6646552876376
# rms: 42.29063273511953
# Coefficient of CBV #1: [0.3307752]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002694186/kplr002694186-2013098041711_llc.fits...
#       -----
# reduced chi2: 1754.8228009552033
# rms: 166.48676941474446
# Coefficient of CBV #1: [1.13819716]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002694186/kplr002694186-2009131105131_llc.fits...
#       -----
# reduced chi2: 2.7905548051397018
# rms: 6.098489466360259
# Coefficient of CBV #1: [0.00177586]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002694186/kplr002694186-2013011073258_llc.fits...
#       -----
# reduced chi2: 2123.830951348265
# rms: 164.94874671280306
# Coefficient of CBV #1: [-1.12611554]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002837332/kplr002837332-2013131215648_llc.fits...
#       -----
# reduced chi2: 21.79908033164794
# rms: 5.629934790933377
# Coefficient of CBV #1: [-0.11103504]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002837332/kplr002837332-2012088054726_llc.fits...
#       -----
# reduced chi2: 1241.6170367220789
# rms: 62.58854696647512
# Coefficient of CBV #1: [2.82075764]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002837332/kplr002837332-2012004120508_llc.fits...
#       -----
# reduced chi2: 370.4695969437373
# rms: 46.19373101438537
# Coefficient of CBV #1: [-1.26507971]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002837332/kplr002837332-2013098041711_llc.fits...
#       -----
# reduced chi2: 80.20556876265012
# rms: 15.676753097107282
# Coefficient of CBV #1: [-0.45958242]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002837332/kplr002837332-2013011073258_llc.fits...
#       -----
# reduced chi2: 3401.88614213515
# rms: 99.25607491315847
# Coefficient of CBV #1: [-5.04667721]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002837332/kplr002837332-2012179063303_llc.fits...
#       -----
# reduced chi2: 1010.280171641684
# rms: 37.18692830315927
# Coefficient of CBV #1: [-2.36994747]
#       -----
# Writing output file ./light_curves_CBV_corr_1/002837332/kplr002837332-2012277125453_llc.fits...
#       -----
# reduced chi2: 91.79611520310317
# rms: 22.241850805987426
# Coefficient of CBV #1: [0.83672685]
#       -----
# Writing output file ./light_curves_CBV_corr_1/003347632/kplr003347632-2012179063303_llc.fits...
#       -----
# reduced chi2: 1894.8742463601934
# rms: 108.18349242808748
# Coefficient of CBV #1: [-1.95424029]
#       -----
# Writing output file ./light_curves_CBV_corr_1/003347632/kplr003347632-2012277125453_llc.fits...
#       -----
# reduced chi2: 2229.2594307901104
# rms: 101.7084627438399
# Coefficient of CBV #1: [-4.30661925]
#       -----
# Writing output file ./light_curves_CBV_corr_1/003347632/kplr003347632-2013098041711_llc.fits...
#       -----
# reduced chi2: 62.96577568923496
# rms: 13.956651032508038
# Coefficient of CBV #1: [-0.36769798]
#       -----
# Writing output file ./light_curves_CBV_corr_1/003347632/kplr003347632-2013011073258_llc.fits...
#       -----
# reduced chi2: 499.67118120371066
# rms: 68.62375693551127
# Coefficient of CBV #1: [-1.21057386]
#       -----
# Writing output file ./light_curves_CBV_corr_1/003347632/kplr003347632-2013131215648_llc.fits...
#       -----
# reduced chi2: 488.5200717818696
# rms: 47.65702191665151
# Coefficient of CBV #1: [-0.79246439]
#       -----
# Writing output file ./light_curves_CBV_corr_1/003347632/kplr003347632-2012088054726_llc.fits...
#       -----
# reduced chi2: 593.2806806713677
# rms: 74.29028398618601
# Coefficient of CBV #1: [1.99973478]
#       -----
# Writing output file ./light_curves_CBV_corr_1/003347632/kplr003347632-2012004120508_llc.fits...
#       -----
# reduced chi2: 164.3666008352892
# rms: 39.51391539948249
# Coefficient of CBV #1: [-0.71606622]
#       -----
# Writing output file ./light_curves_CBV_corr_1/005781475/kplr005781475-2012277125453_llc.fits...
#       -----
# reduced chi2: 6770.956545886335
# rms: 164.98783518816046
# Coefficient of CBV #1: [4.76877394]
#       -----
# Writing output file ./light_curves_CBV_corr_1/005781475/kplr005781475-2013098041711_llc.fits...
#       -----
# reduced chi2: 1641.6004468156582
# rms: 68.48658047327989
# Coefficient of CBV #1: [2.26920509]
#       -----
# Writing output file ./light_curves_CBV_corr_1/005781475/kplr005781475-2013011073258_llc.fits...
#       -----
# reduced chi2: 3985.836562645922
# rms: 105.2975942115496
# Coefficient of CBV #1: [4.00079259]
#       -----
# Writing output file ./light_curves_CBV_corr_1/005781475/kplr005781475-2013131215648_llc.fits...
#       -----
# reduced chi2: 524.884912076626
# rms: 40.38943999685428
# Coefficient of CBV #1: [0.84257182]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2010174085026_llc.fits...
#       -----
# reduced chi2: 33213.15629649169
# rms: 908.3932124871644
# Coefficient of CBV #1: [-2.19017077]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2011271113734_llc.fits...
#       -----
# reduced chi2: 18424.210617496345
# rms: 816.3490901795814
# Coefficient of CBV #1: [2.21275867]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2013098041711_llc.fits...
#       -----
# reduced chi2: 15564.85129464948
# rms: 681.3945401614274
# Coefficient of CBV #1: [1.79015417]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2013011073258_llc.fits...
#       -----
# reduced chi2: 6689.936197623864
# rms: 449.88712367601454
# Coefficient of CBV #1: [-0.74638545]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2010265121752_llc.fits...
#       -----
# reduced chi2: 1248.6562003393406
# rms: 211.6875058692762
# Coefficient of CBV #1: [-0.35759978]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2012277125453_llc.fits...
#       -----
# reduced chi2: 6147.60946243536
# rms: 475.0486769731096
# Coefficient of CBV #1: [1.03575762]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2012179063303_llc.fits...
#       -----
# reduced chi2: 28203.795643949892
# rms: 828.7720539856712
# Coefficient of CBV #1: [-1.86638487]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2011073133259_llc.fits...
#       -----
# reduced chi2: 116.49964359580306
# rms: 57.74249768969322
# Coefficient of CBV #1: [-0.0595142]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2010355172524_llc.fits...
#       -----
# reduced chi2: 7579.671144428079
# rms: 325.81373229341375
# Coefficient of CBV #1: [-0.39517777]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2013131215648_llc.fits...
#       -----
# reduced chi2: 3699.4814101884945
# rms: 305.42922822465533
# Coefficient of CBV #1: [0.2945965]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2010078095331_llc.fits...
#       -----
# reduced chi2: 48981.32096281975
# rms: 1197.469759402181
# Coefficient of CBV #1: [3.32433218]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2012088054726_llc.fits...
#       -----
# reduced chi2: 2684.3836929155145
# rms: 291.71973799472386
# Coefficient of CBV #1: [0.41385978]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2011177032512_llc.fits...
#       -----
# reduced chi2: 4761.809594493898
# rms: 342.51073576141636
# Coefficient of CBV #1: [0.16654235]
#       -----
# Writing output file ./light_curves_CBV_corr_1/006932990/kplr006932990-2012004120508_llc.fits...
#       -----
# reduced chi2: 41247.939288394926
# rms: 833.7566817759312
# Coefficient of CBV #1: [2.61078402]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007175757/kplr007175757-2012277125453_llc.fits...
#       -----
# reduced chi2: 7.811042814699375
# rms: 7.313673635884393
# Coefficient of CBV #1: [0.33486222]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007175757/kplr007175757-2013011073258_llc.fits...
#       -----
# reduced chi2: 53.45320139186053
# rms: 24.581495649647454
# Coefficient of CBV #1: [1.71505337]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007175757/kplr007175757-2013098041711_llc.fits...
#       -----
# reduced chi2: 236.4132967451927
# rms: 35.42350337363217
# Coefficient of CBV #1: [3.74132244]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007175757/kplr007175757-2013131215648_llc.fits...
#       -----
# reduced chi2: 4.573555803385102
# rms: 6.298493861092626
# Coefficient of CBV #1: [-0.37024767]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007523720/kplr007523720-2012277125453_llc.fits...
#       -----
# reduced chi2: 44.80539956705015
# rms: 12.610782595415266
# Coefficient of CBV #1: [-0.21859206]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007523720/kplr007523720-2013098041711_llc.fits...
#       -----
# reduced chi2: 1196.761793416814
# rms: 57.19176041309347
# Coefficient of CBV #1: [3.0776993]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007523720/kplr007523720-2013011073258_llc.fits...
#       -----
# reduced chi2: 702.8455607245422
# rms: 56.44759067441111
# Coefficient of CBV #1: [-2.64602769]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007523720/kplr007523720-2013131215648_llc.fits...
#       -----
# reduced chi2: 59.488070776674846
# rms: 12.861061103017752
# Coefficient of CBV #1: [0.2689253]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007610713/kplr007610713-2012004120508_llc.fits...
#       -----
# reduced chi2: 1558.0704001647382
# rms: 95.50714968444161
# Coefficient of CBV #1: [-1.22700151]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007610713/kplr007610713-2012088054726_llc.fits...
#       -----
# reduced chi2: 122.14313657552728
# rms: 24.27493995247225
# Coefficient of CBV #1: [0.30738781]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007610713/kplr007610713-2013131215648_llc.fits...
#       -----
# reduced chi2: 10.564138980844548
# rms: 6.612509021235988
# Coefficient of CBV #1: [0.02679471]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007610713/kplr007610713-2012277125453_llc.fits...
#       -----
# reduced chi2: 1127.7090707369932
# rms: 88.72060304442878
# Coefficient of CBV #1: [-1.00696332]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007610713/kplr007610713-2012179063303_llc.fits...
#       -----
# reduced chi2: 353.40750166840036
# rms: 37.28632069853989
# Coefficient of CBV #1: [0.3341153]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007610713/kplr007610713-2013011073258_llc.fits...
#       -----
# reduced chi2: 905.5727214814315
# rms: 73.7772000760282
# Coefficient of CBV #1: [-0.79078113]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007610713/kplr007610713-2011271113734_llc.fits...
#       -----
# reduced chi2: 467.2277229871888
# rms: 56.3123820573843
# Coefficient of CBV #1: [0.52390594]
#       -----
# Writing output file ./light_curves_CBV_corr_1/007610713/kplr007610713-2013098041711_llc.fits...
#       -----
# reduced chi2: 79.16249098418058
# rms: 25.93224642443214
# Coefficient of CBV #1: [-0.11369802]
#       -----
# Writing output file ./light_curves_CBV_corr_1/008946433/kplr008946433-2012277125453_llc.fits...
#       -----
# reduced chi2: 899.2385702062777
# rms: 109.29662028273017
# Coefficient of CBV #1: [-0.75325339]
#       -----
# Writing output file ./light_curves_CBV_corr_1/008946433/kplr008946433-2013011073258_llc.fits...
#       -----
# reduced chi2: 2332.9361381965214
# rms: 116.05973072426261
# Coefficient of CBV #1: [-1.05090012]
#       -----
# Writing output file ./light_curves_CBV_corr_1/008946433/kplr008946433-2013098041711_llc.fits...
#       -----
# reduced chi2: 108.18995156225846
# rms: 15.761682530306427
# Coefficient of CBV #1: [-0.01644795]
#       -----
# Writing output file ./light_curves_CBV_corr_1/008946433/kplr008946433-2013131215648_llc.fits...
#       -----
# reduced chi2: 120.90010789835742
# rms: 34.1429665778536
# Coefficient of CBV #1: [-0.0435292]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009145961/kplr009145961-2013098041711_llc.fits...
#       -----
# reduced chi2: 51.539182134793926
# rms: 35.252063302389914
# Coefficient of CBV #1: [-0.79456915]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009145961/kplr009145961-2013011073258_llc.fits...
#       -----
# reduced chi2: 464.67738935028393
# rms: 38.76257167687172
# Coefficient of CBV #1: [0.86679538]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009145961/kplr009145961-2012277125453_llc.fits...
#       -----
# reduced chi2: 1936.969917045576
# rms: 90.36467833012561
# Coefficient of CBV #1: [2.08222174]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009145961/kplr009145961-2013131215648_llc.fits...
#       -----
# reduced chi2: 87.8257508629339
# rms: 15.908660938585117
# Coefficient of CBV #1: [-0.33447802]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009215110/kplr009215110-2013011073258_llc.fits...
#       -----
# reduced chi2: 35.58648177427044
# rms: 13.750252902968784
# Coefficient of CBV #1: [0.29122922]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009215110/kplr009215110-2011271113734_llc.fits...
#       -----
# reduced chi2: 17.058308669870065
# rms: 9.358136615858644
# Coefficient of CBV #1: [-0.16518599]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009215110/kplr009215110-2013098041711_llc.fits...
#       -----
# reduced chi2: 21.82539109521023
# rms: 7.641451085327492
# Coefficient of CBV #1: [-0.24028572]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009215110/kplr009215110-2012277125453_llc.fits...
#       -----
# reduced chi2: 17.330630318693007
# rms: 9.385200357072062
# Coefficient of CBV #1: [-0.07650917]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009215110/kplr009215110-2012179063303_llc.fits...
#       -----
# reduced chi2: 38.457158534744394
# rms: 18.751535036312443
# Coefficient of CBV #1: [0.38791049]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009215110/kplr009215110-2012088054726_llc.fits...
#       -----
# reduced chi2: 476.00781976070215
# rms: 36.04139144080728
# Coefficient of CBV #1: [1.13839008]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009215110/kplr009215110-2012004120508_llc.fits...
#       -----
# reduced chi2: 126.46619072843566
# rms: 25.716845713469407
# Coefficient of CBV #1: [0.61092517]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009215110/kplr009215110-2013131215648_llc.fits...
#       -----
# reduced chi2: 114.68792348932463
# rms: 32.364841412373636
# Coefficient of CBV #1: [0.64856879]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009650712/kplr009650712-2011271113734_llc.fits...
#       -----
# reduced chi2: 10554.093788539481
# rms: 289.65606348862815
# Coefficient of CBV #1: [-1.2498144]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009650712/kplr009650712-2013098041711_llc.fits...
#       -----
# reduced chi2: 4231.990498055573
# rms: 171.72542364549025
# Coefficient of CBV #1: [0.1981666]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009650712/kplr009650712-2013011073258_llc.fits...
#       -----
# reduced chi2: 54603.638038739846
# rms: 684.42277342545
# Coefficient of CBV #1: [-4.46793207]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009650712/kplr009650712-2012179063303_llc.fits...
#       -----
# reduced chi2: 1511.7308769008182
# rms: 95.12451472556177
# Coefficient of CBV #1: [0.47813436]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009650712/kplr009650712-2012277125453_llc.fits...
#       -----
# reduced chi2: 3974.8114775524273
# rms: 161.69226013089272
# Coefficient of CBV #1: [-0.8675057]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009650712/kplr009650712-2013131215648_llc.fits...
#       -----
# reduced chi2: 3712.50944527838
# rms: 144.2362773244064
# Coefficient of CBV #1: [1.01997823]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009650712/kplr009650712-2012004120508_llc.fits...
#       -----
# reduced chi2: 8787.61694179432
# rms: 277.0003864524541
# Coefficient of CBV #1: [-1.55682276]
#       -----
# Writing output file ./light_curves_CBV_corr_1/009650712/kplr009650712-2012088054726_llc.fits...
#       -----
# reduced chi2: 16494.421185015763
# rms: 350.41672577974356
# Coefficient of CBV #1: [-2.195522]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010645722/kplr010645722-2012088054726_llc.fits...
#       -----
# reduced chi2: 174.42456105729204
# rms: 24.584371445320016
# Coefficient of CBV #1: [-0.27110856]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010645722/kplr010645722-2012004120508_llc.fits...
#       -----
# reduced chi2: 685.7504508468093
# rms: 58.932293473975264
# Coefficient of CBV #1: [-1.38773933]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010645722/kplr010645722-2013131215648_llc.fits...
#       -----
# reduced chi2: 68.03337673443932
# rms: 15.381509813462184
# Coefficient of CBV #1: [-0.16813857]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010645722/kplr010645722-2013011073258_llc.fits...
#       -----
# reduced chi2: 461.30048304648165
# rms: 55.21601854164046
# Coefficient of CBV #1: [-0.98726301]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010645722/kplr010645722-2013098041711_llc.fits...
#       -----
# reduced chi2: 700.1524977553217
# rms: 36.64031003150998
# Coefficient of CBV #1: [-1.37396139]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010645722/kplr010645722-2011271113734_llc.fits...
#       -----
# reduced chi2: 170.96889613617682
# rms: 31.9905677107463
# Coefficient of CBV #1: [-0.62953676]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010645722/kplr010645722-2012277125453_llc.fits...
#       -----
# reduced chi2: 44.65586838308107
# rms: 16.447560119743784
# Coefficient of CBV #1: [0.09334402]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010645722/kplr010645722-2012179063303_llc.fits...
#       -----
# reduced chi2: 969.9343976110044
# rms: 68.95857844023286
# Coefficient of CBV #1: [1.18668692]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010798894/kplr010798894-2013098041711_llc.fits...
#       -----
# reduced chi2: 78.22451517541309
# rms: 15.124730014201116
# Coefficient of CBV #1: [0.1919334]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010798894/kplr010798894-2013011073258_llc.fits...
#       -----
# reduced chi2: 226.1461300674024
# rms: 31.052884938546516
# Coefficient of CBV #1: [0.08147154]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010798894/kplr010798894-2013131215648_llc.fits...
#       -----
# reduced chi2: 647.5534678348739
# rms: 53.10487541581077
# Coefficient of CBV #1: [-0.95471024]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010841941/kplr010841941-2012277125453_llc.fits...
#       -----
# reduced chi2: 7182.355536000417
# rms: 151.58145635431907
# Coefficient of CBV #1: [5.69571717]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010841941/kplr010841941-2012179063303_llc.fits...
#       -----
# reduced chi2: 316.6053685225233
# rms: 44.94893050794952
# Coefficient of CBV #1: [-1.10303927]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010841941/kplr010841941-2013098041711_llc.fits...
#       -----
# reduced chi2: 290.3701244212751
# rms: 31.53754949660701
# Coefficient of CBV #1: [-1.18148693]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010841941/kplr010841941-2013011073258_llc.fits...
#       -----
# reduced chi2: 818.8485554775866
# rms: 73.99748906225022
# Coefficient of CBV #1: [-1.83988767]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010841941/kplr010841941-2013131215648_llc.fits...
#       -----
# reduced chi2: 52.88671367281982
# rms: 18.546164893661796
# Coefficient of CBV #1: [-0.33392659]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010841941/kplr010841941-2012004120508_llc.fits...
#       -----
# reduced chi2: 174.97822397422354
# rms: 34.15524051360942
# Coefficient of CBV #1: [-0.86806369]
#       -----
# Writing output file ./light_curves_CBV_corr_1/010841941/kplr010841941-2012088054726_llc.fits...
#       -----
# reduced chi2: 473.91632045816493
# rms: 48.67245508857621
# Coefficient of CBV #1: [-1.26479877]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011413175/kplr011413175-2013131215648_llc.fits...
#       -----
# reduced chi2: 40.21445768729553
# rms: 11.622010707399705
# Coefficient of CBV #1: [0.15168395]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011413175/kplr011413175-2013098041711_llc.fits...
#       -----
# reduced chi2: 69.61588180897463
# rms: 21.984689140523304
# Coefficient of CBV #1: [-0.14575272]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011413175/kplr011413175-2013011073258_llc.fits...
#       -----
# reduced chi2: 95.58020488655048
# rms: 24.545284345149472
# Coefficient of CBV #1: [-0.28773601]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011606854/kplr011606854-2012004120508_llc.fits...
#       -----
# reduced chi2: 3132.2061203174208
# rms: 76.04939406609599
# Coefficient of CBV #1: [-4.0902479]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011606854/kplr011606854-2011177032512_llc.fits...
#       -----
# reduced chi2: 70.71400889646632
# rms: 19.578237241798934
# Coefficient of CBV #1: [-0.78409779]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011606854/kplr011606854-2012088054726_llc.fits...
#       -----
# reduced chi2: 45.81453494418267
# rms: 12.806668063532292
# Coefficient of CBV #1: [-0.42950868]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011606854/kplr011606854-2013131215648_llc.fits...
#       -----
# reduced chi2: 79.39566774257479
# rms: 24.184935773895234
# Coefficient of CBV #1: [-0.74119434]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011606854/kplr011606854-2011073133259_llc.fits...
#       -----
# reduced chi2: 735.4511546950542
# rms: 69.96303293287296
# Coefficient of CBV #1: [2.34029529]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011606854/kplr011606854-2010355172524_llc.fits...
#       -----
# reduced chi2: 591.6454533370954
# rms: 32.68902630072577
# Coefficient of CBV #1: [-1.839076]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011606854/kplr011606854-2012277125453_llc.fits...
#       -----
# reduced chi2: 3403.2209915726257
# rms: 105.22692415222038
# Coefficient of CBV #1: [-5.08283475]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011606854/kplr011606854-2012179063303_llc.fits...
#       -----
# reduced chi2: 168.21186808103474
# rms: 30.316024868474642
# Coefficient of CBV #1: [-1.22927975]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011606854/kplr011606854-2010265121752_llc.fits...
#       -----
# reduced chi2: 2239.2527885730915
# rms: 85.44450077458933
# Coefficient of CBV #1: [4.10894925]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011606854/kplr011606854-2013011073258_llc.fits...
#       -----
# reduced chi2: 1725.7421005019235
# rms: 55.86352874387326
# Coefficient of CBV #1: [-2.88720277]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011606854/kplr011606854-2013098041711_llc.fits...
#       -----
# reduced chi2: 203.95896973817193
# rms: 26.378842517797942
# Coefficient of CBV #1: [1.33721899]
#       -----
# Writing output file ./light_curves_CBV_corr_1/011606854/kplr011606854-2011271113734_llc.fits...
#       -----
# reduced chi2: 6803.929300625897
# rms: 108.04210783785994
# Coefficient of CBV #1: [7.2985228]
#       -----
# Writing output file ./light_curves_CBV_corr_1/012010193/kplr012010193-2013131215648_llc.fits...
#       -----
# reduced chi2: 2.671702146457311
# rms: 4.06553730698271
# Coefficient of CBV #1: [0.05355326]
#       -----
# Writing output file ./light_curves_CBV_corr_1/012010193/kplr012010193-2013098041711_llc.fits...
#       -----
# reduced chi2: 67.66493940963946
# rms: 15.887179963128881
# Coefficient of CBV #1: [0.87134034]
#       -----
# Writing output file ./light_curves_CBV_corr_1/012010193/kplr012010193-2013011073258_llc.fits...
#       -----
# reduced chi2: 297.90748973371086
# rms: 39.00634524847729
# Coefficient of CBV #1: [-1.34119025]
#       -----
# Writing output file ./light_curves_CBV_corr_1/012010193/kplr012010193-2012277125453_llc.fits...
#       -----
# reduced chi2: 3473.0059558317616
# rms: 162.07558449328567
# Coefficient of CBV #1: [2.48116995]
#       -----
# Writing output file ./light_curves_CBV_corr_1/012158940/kplr012158940-2011177032512_llc.fits...
#       -----
# reduced chi2: 4763.757895833088
# rms: 246.67306389148115
# Coefficient of CBV #1: [0.68899837]
#       -----
# Writing output file ./light_curves_CBV_corr_1/012158940/kplr012158940-2012004120508_llc.fits...
#       -----
# reduced chi2: 2385.4021625903983
# rms: 120.72035795280489
# Coefficient of CBV #1: [1.04073785]
#       -----
# Writing output file ./light_curves_CBV_corr_1/012158940/kplr012158940-2012088054726_llc.fits...
#       -----
# reduced chi2: 14753.175753103045
# rms: 346.55445510404235
# Coefficient of CBV #1: [-2.46980471]
#       -----
# Writing output file ./light_curves_CBV_corr_1/012158940/kplr012158940-2013131215648_llc.fits...
#       -----
# reduced chi2: 99.35897261473472
# rms: 36.875410600415165
# Coefficient of CBV #1: [-0.02411556]
#       -----
# Writing output file ./light_curves_CBV_corr_1/012158940/kplr012158940-2013011073258_llc.fits...
#       -----
# reduced chi2: 54391.63893094164
# rms: 698.5067029583013
# Coefficient of CBV #1: [-3.70772857]
#       -----
# Writing output file ./light_curves_CBV_corr_1/012158940/kplr012158940-2011271113734_llc.fits...
#       -----
# reduced chi2: 6982.712326051185
# rms: 277.16677361009516
# Coefficient of CBV #1: [-1.7244781]
#       -----
# Writing output file ./light_curves_CBV_corr_1/012158940/kplr012158940-2013098041711_llc.fits...
#       -----
# reduced chi2: 9561.775080429024
# rms: 158.10283072862345
# Coefficient of CBV #1: [2.94529981]
#       -----
# Writing output file ./light_curves_CBV_corr_1/012158940/kplr012158940-2012179063303_llc.fits...
#       -----
# reduced chi2: 5362.094759281792
# rms: 264.2113457216505
# Coefficient of CBV #1: [1.22674211]
#       -----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
#       1 for object_index in range(len(names)):
# ----> 2     detrend_object(object_index,iterate=False,listbv='1',fitmethod='llsq')
#
# Input In [9], in detrend_object(object_index, listbv, verbose, iterate, sigma, fitmethod, fitpower)
#       3 object_path = (Datafolder)+str(names[object_index])+'/'
#       4 for index in range(len(os.listdir(object_path))):
# ----> 5     detrend_curve(object_path,index,listbv,verbose,iterate,sigma)
#
# Input In [9], in detrend_curve(object_path, curve_index, listbv, verbose, iterate, sigma, fitmethod, fitpower)
#      16     quarter = hdul[0].header['QUARTER']
#      18 CBV_path = CBVs_path+str(CBVs_names[quarter])
# ---> 19 kepcotrend(curve_path,CBV_path,listbv,outfile=new_curve_path,
#      20            overwrite=True,verbose=verbose,iterate=iterate,sigma=sigma,fitmethod=fitmethod,fitpower=fitpower)
#
# File ~/miniforge3/envs/Fermilab_torch_sum/lib/python3.9/site-packages/pyke/kepcotrend.py:669, in kepcotrend(infile, bvfile, listbv, outfile, fitmethod, fitpower, iterate, sigma, maskfile, scinterp, plot, noninteractive, overwrite, verbose, logfile)
#     666 except KeyError:
#     667     version = 1
# --> 669 table = instr[1].data
#     670 if version == 1:
#     671     if str(instr[1].header['DATATYPE']) == 'long cadence':
#
# File ~/miniforge3/envs/Fermilab_torch_sum/lib/python3.9/site-packages/astropy/utils/decorators.py:777, in lazyproperty.__get__(self, obj, owner)
#     775         val = obj_dict.get(self._key, _NotFound)
#     776         if val is _NotFound:
# --> 777             val = self.fget(obj)
#     778             obj_dict[self._key] = val
#     779 return val
#
# File ~/miniforge3/envs/Fermilab_torch_sum/lib/python3.9/site-packages/astropy/io/fits/hdu/table.py:400, in _TableBaseHDU.data(self)
#     398 @lazyproperty
#     399 def data(self):
# --> 400     data = self._get_tbdata()
#     401     data._coldefs = self.columns
#     402     data._character_as_bytes = self._character_as_bytes
#
# File ~/miniforge3/envs/Fermilab_torch_sum/lib/python3.9/site-packages/astropy/io/fits/hdu/table.py:170, in _TableLikeHDU._get_tbdata(self)
#     167     data = raw_data[:tbsize].view(dtype=columns.dtype,
#     168                                   type=np.rec.recarray)
#     169 else:
# --> 170     raw_data = self._get_raw_data(self._nrows, columns.dtype,
#     171                                   self._data_offset)
#     172     if raw_data is None:
#     173         # This can happen when a brand new table HDU is being created
#     174         # and no data has been assigned to the columns, which case just
#     175         # return an empty array
#     176         raw_data = np.array([], dtype=columns.dtype)
#
# File ~/miniforge3/envs/Fermilab_torch_sum/lib/python3.9/site-packages/astropy/io/fits/hdu/base.py:522, in _BaseHDU._get_raw_data(self, shape, code, offset)
#     519     return np.ndarray(shape, dtype=code, buffer=self._buffer,
#     520                       offset=offset)
#     521 elif self._file:
# --> 522     return self._file.readarray(offset=offset, dtype=code, shape=shape)
#     523 else:
#     524     return None
#
# File ~/miniforge3/envs/Fermilab_torch_sum/lib/python3.9/site-packages/astropy/io/fits/file.py:300, in _File.readarray(self, size, offset, dtype, shape)
#     297 # This would also work:
#     298 # self._file.seek(0, 2)   # moves to the end
#     299 try:
# --> 300     self._mmap = mmap.mmap(self._file.fileno(), 0,
#     301                            access=access_mode,
#     302                            offset=0)
#     303 except OSError as exc:
#     304     # NOTE: mode='readonly' results in the memory-mapping
#     305     # using the ACCESS_COPY mode in mmap so that users can
#    (...)
#     310     # least allows the file to be opened even if the
#     311     # resulting arrays will be truly read-only.
#     312     if exc.errno == errno.ENOMEM and self.mode == 'readonly':
#
# KeyboardInterrupt:

# %%
for object_index in range(len(names)):
    detrend_object(object_index,iterate=False,listbv='1 2',fitmethod='llsq')
# Out:
# Writing output file ./light_curves_CBV_corr_2/002694186/kplr002694186-2013131215648_llc.fits...
#       -----
# reduced chi2: 306.2822042855846
# rms: 45.26906675180596
# Coefficient of CBV #1: [-0.23660686]
# Coefficient of CBV #2: [-0.08330189]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002694186/kplr002694186-2011177032512_llc.fits...
#       -----
# reduced chi2: 386.5396330149902
# rms: 56.60370533855868
# Coefficient of CBV #1: [0.06737384]
# Coefficient of CBV #2: [0.4768033]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002694186/kplr002694186-2012004120508_llc.fits...
#       -----
# reduced chi2: 2896.7255904147296
# rms: 219.06047771024885
# Coefficient of CBV #1: [-1.0919598]
# Coefficient of CBV #2: [-0.68868283]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002694186/kplr002694186-2012088054726_llc.fits...
#       -----
# reduced chi2: 15678.967953273059
# rms: 435.5000232965092
# Coefficient of CBV #1: [-3.22975324]
# Coefficient of CBV #2: [-0.11522959]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002694186/kplr002694186-2012277125453_llc.fits...
#       -----
# reduced chi2: 822.2959781620881
# rms: 88.9367092385361
# Coefficient of CBV #1: [-0.66406413]
# Coefficient of CBV #2: [0.41419049]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002694186/kplr002694186-2012179063303_llc.fits...
#       -----
# reduced chi2: 254.76292552318174
# rms: 40.596309728240605
# Coefficient of CBV #1: [-0.3811399]
# Coefficient of CBV #2: [0.04339006]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002694186/kplr002694186-2011073133259_llc.fits...
#       -----
# reduced chi2: 322.80234826756174
# rms: 71.6797663792798
# Coefficient of CBV #1: [0.01143276]
# Coefficient of CBV #2: [0.42058768]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002694186/kplr002694186-2010355172524_llc.fits...
#       -----
# reduced chi2: 1485.1781422775407
# rms: 120.26632646719884
# Coefficient of CBV #1: [-0.88249032]
# Coefficient of CBV #2: [0.36399019]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002694186/kplr002694186-2011271113734_llc.fits...
#       -----
# reduced chi2: 224.7323978554274
# rms: 46.5245274008245
# Coefficient of CBV #1: [0.33137835]
# Coefficient of CBV #2: [0.20095179]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002694186/kplr002694186-2013098041711_llc.fits...
#       -----
# reduced chi2: 1766.5937134891428
# rms: 167.00979261282356
# Coefficient of CBV #1: [1.16731882]
# Coefficient of CBV #2: [0.1068658]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002694186/kplr002694186-2009131105131_llc.fits...
#       -----
# reduced chi2: 5.261604168581859
# rms: 8.36480997379581
# Coefficient of CBV #1: [0.00179275]
# Coefficient of CBV #2: [-0.01528328]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002694186/kplr002694186-2013011073258_llc.fits...
#       -----
# reduced chi2: 2138.1537207505776
# rms: 165.5294793639628
# Coefficient of CBV #1: [-1.119728]
# Coefficient of CBV #2: [-0.12081796]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002837332/kplr002837332-2013131215648_llc.fits...
#       -----
# reduced chi2: 34.41340651131312
# rms: 7.067225853316849
# Coefficient of CBV #1: [0.05667397]
# Coefficient of CBV #2: [-0.31545219]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002837332/kplr002837332-2012088054726_llc.fits...
#       -----
# reduced chi2: 1280.3083203360143
# rms: 63.5137434616493
# Coefficient of CBV #1: [2.8196574]
# Coefficient of CBV #2: [-0.57444646]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002837332/kplr002837332-2012004120508_llc.fits...
#       -----
# reduced chi2: 389.95983770414927
# rms: 47.35564025867541
# Coefficient of CBV #1: [-1.2688113]
# Coefficient of CBV #2: [0.35834254]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002837332/kplr002837332-2013098041711_llc.fits...
#       -----
# reduced chi2: 172.9548555624861
# rms: 23.03635375206155
# Coefficient of CBV #1: [-0.21075776]
# Coefficient of CBV #2: [0.9721109]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002837332/kplr002837332-2013011073258_llc.fits...
#       -----
# reduced chi2: 4038.7315390306862
# rms: 108.56036870738946
# Coefficient of CBV #1: [-4.85861562]
# Coefficient of CBV #2: [-3.14286884]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002837332/kplr002837332-2012179063303_llc.fits...
#       -----
# reduced chi2: 1018.9431205827384
# rms: 37.38270554053327
# Coefficient of CBV #1: [-2.36901246]
# Coefficient of CBV #2: [0.29529096]
#       -----
# Writing output file ./light_curves_CBV_corr_2/002837332/kplr002837332-2012277125453_llc.fits...
#       -----
# reduced chi2: 118.90757755168487
# rms: 25.306949025256436
# Coefficient of CBV #1: [0.86052868]
# Coefficient of CBV #2: [0.65398209]
#       -----
# Writing output file ./light_curves_CBV_corr_2/003347632/kplr003347632-2012179063303_llc.fits...
#       -----
# reduced chi2: 1936.233845965265
# rms: 109.28446123447156
# Coefficient of CBV #1: [-1.95510662]
# Coefficient of CBV #2: [-0.33071943]
#       -----
# Writing output file ./light_curves_CBV_corr_2/003347632/kplr003347632-2012277125453_llc.fits...
#       -----
# reduced chi2: 2387.8581583200885
# rms: 105.17816250020302
# Coefficient of CBV #1: [-4.27604866]
# Coefficient of CBV #2: [-1.40393651]
#       -----
# Writing output file ./light_curves_CBV_corr_2/003347632/kplr003347632-2013098041711_llc.fits...
#       -----
# reduced chi2: 161.4280465914035
# rms: 22.321199547337674
# Coefficient of CBV #1: [0.02873239]
# Coefficient of CBV #2: [1.5636078]
#       -----
# Writing output file ./light_curves_CBV_corr_2/003347632/kplr003347632-2013011073258_llc.fits...
#       -----
# reduced chi2: 1162.3648359615202
# rms: 104.84260633974391
# Coefficient of CBV #1: [-0.5598845]
# Coefficient of CBV #2: [5.64134901]
#       -----
# Writing output file ./light_curves_CBV_corr_2/003347632/kplr003347632-2013131215648_llc.fits...
#       -----
# reduced chi2: 493.75154941316435
# rms: 47.891090471444286
# Coefficient of CBV #1: [-0.81319401]
# Coefficient of CBV #2: [-0.11861601]
#       -----
# Writing output file ./light_curves_CBV_corr_2/003347632/kplr003347632-2012088054726_llc.fits...
#       -----
# reduced chi2: 599.6919251025406
# rms: 74.66907640312407
# Coefficient of CBV #1: [2.00012293]
# Coefficient of CBV #2: [-0.23869791]
#       -----
# Writing output file ./light_curves_CBV_corr_2/003347632/kplr003347632-2012004120508_llc.fits...
#       -----
# reduced chi2: 286.205033630957
# rms: 52.229470810090206
# Coefficient of CBV #1: [-0.70942261]
# Coefficient of CBV #2: [-0.8687474]
#       -----
# Writing output file ./light_curves_CBV_corr_2/005781475/kplr005781475-2012277125453_llc.fits...
#       -----
# reduced chi2: 6994.71933130064
# rms: 167.47883792276843
# Coefficient of CBV #1: [4.75313021]
# Coefficient of CBV #2: [-0.99643494]
#       -----
# Writing output file ./light_curves_CBV_corr_2/005781475/kplr005781475-2013098041711_llc.fits...
#       -----
# reduced chi2: 1893.4847277705899
# rms: 73.51034229939205
# Coefficient of CBV #1: [1.96206681]
# Coefficient of CBV #2: [1.0674316]
#       -----
# Writing output file ./light_curves_CBV_corr_2/005781475/kplr005781475-2013011073258_llc.fits...
#       -----
# reduced chi2: 4006.7880773967677
# rms: 105.59338480213923
# Coefficient of CBV #1: [3.9929957]
# Coefficient of CBV #2: [-0.37228266]
#       -----
# Writing output file ./light_curves_CBV_corr_2/005781475/kplr005781475-2013131215648_llc.fits...
#       -----
# reduced chi2: 541.5423402234183
# rms: 41.013080353099255
# Coefficient of CBV #1: [0.89832701]
# Coefficient of CBV #2: [0.21653567]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2010174085026_llc.fits...
#       -----
# reduced chi2: 34619.44290433713
# rms: 928.5513764671674
# Coefficient of CBV #1: [-2.18841567]
# Coefficient of CBV #2: [0.5658367]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2011271113734_llc.fits...
#       -----
# reduced chi2: 18498.19219563077
# rms: 817.756790412884
# Coefficient of CBV #1: [2.21261511]
# Coefficient of CBV #2: [-0.15727629]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2013098041711_llc.fits...
#       -----
# reduced chi2: 15625.821249107366
# rms: 682.7089088518871
# Coefficient of CBV #1: [1.74249449]
# Coefficient of CBV #2: [0.14170389]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2013011073258_llc.fits...
#       -----
# reduced chi2: 8401.705659378345
# rms: 503.73137155483306
# Coefficient of CBV #1: [-0.85089736]
# Coefficient of CBV #2: [1.07547307]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2010265121752_llc.fits...
#       -----
# reduced chi2: 1352.114284029265
# rms: 220.29571286986598
# Coefficient of CBV #1: [-0.35777639]
# Coefficient of CBV #2: [-0.19256511]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2012277125453_llc.fits...
#       -----
# reduced chi2: 7354.912002552201
# rms: 519.2504203608314
# Coefficient of CBV #1: [1.02810217]
# Coefficient of CBV #2: [0.60409818]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2012179063303_llc.fits...
#       -----
# reduced chi2: 28307.160344378502
# rms: 830.3454061002286
# Coefficient of CBV #1: [-1.865912]
# Coefficient of CBV #2: [-0.14130863]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2011073133259_llc.fits...
#       -----
# reduced chi2: 167.44878862120063
# rms: 69.20254414007084
# Coefficient of CBV #1: [-0.05876703]
# Coefficient of CBV #2: [0.11969042]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2010355172524_llc.fits...
#       -----
# reduced chi2: 20221.619984191424
# rms: 531.8547640038313
# Coefficient of CBV #1: [-0.40817754]
# Coefficient of CBV #2: [-1.8136487]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2013131215648_llc.fits...
#       -----
# reduced chi2: 4500.389284863862
# rms: 336.3493577921959
# Coefficient of CBV #1: [0.40062378]
# Coefficient of CBV #2: [0.27657738]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2010078095331_llc.fits...
#       -----
# reduced chi2: 49018.26024292476
# rms: 1197.6730075093942
# Coefficient of CBV #1: [3.32454601]
# Coefficient of CBV #2: [-0.07351665]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2012088054726_llc.fits...
#       -----
# reduced chi2: 4648.9058315826305
# rms: 383.9508491998023
# Coefficient of CBV #1: [0.40846614]
# Coefficient of CBV #2: [0.74467873]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2011177032512_llc.fits...
#       -----
# reduced chi2: 11120.422979465693
# rms: 523.317029968287
# Coefficient of CBV #1: [0.16585707]
# Coefficient of CBV #2: [1.30482701]
#       -----
# Writing output file ./light_curves_CBV_corr_2/006932990/kplr006932990-2012004120508_llc.fits...
#       -----
# reduced chi2: 43722.45163345739
# rms: 857.8392005977502
# Coefficient of CBV #1: [2.62198159]
# Coefficient of CBV #2: [0.76165807]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007175757/kplr007175757-2012277125453_llc.fits...
#       -----
# reduced chi2: 16.80687003907052
# rms: 10.726372476189749
# Coefficient of CBV #1: [0.3769103]
# Coefficient of CBV #2: [-1.31545944]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007175757/kplr007175757-2013011073258_llc.fits...
#       -----
# reduced chi2: 103.49167669953655
# rms: 34.199256838939206
# Coefficient of CBV #1: [1.6623924]
# Coefficient of CBV #2: [-2.67179124]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007175757/kplr007175757-2013098041711_llc.fits...
#       -----
# reduced chi2: 245.01097311394838
# rms: 36.04791662424644
# Coefficient of CBV #1: [3.49775507]
# Coefficient of CBV #2: [0.78601124]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007175757/kplr007175757-2013131215648_llc.fits...
#       -----
# reduced chi2: 8.33114341211123
# rms: 8.499684451182713
# Coefficient of CBV #1: [-0.6661507]
# Coefficient of CBV #2: [0.71634579]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007523720/kplr007523720-2012277125453_llc.fits...
#       -----
# reduced chi2: 45.292589668014664
# rms: 12.67870593116271
# Coefficient of CBV #1: [-0.21735768]
# Coefficient of CBV #2: [0.06091204]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007523720/kplr007523720-2013098041711_llc.fits...
#       -----
# reduced chi2: 2233.509810233937
# rms: 78.12281866110338
# Coefficient of CBV #1: [2.31745203]
# Coefficient of CBV #2: [3.26820732]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007523720/kplr007523720-2013011073258_llc.fits...
#       -----
# reduced chi2: 739.3401940720616
# rms: 57.87566392351611
# Coefficient of CBV #1: [-3.47708994]
# Coefficient of CBV #2: [-8.31318198]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007523720/kplr007523720-2013131215648_llc.fits...
#       -----
# reduced chi2: 59.79729206230523
# rms: 12.889699331491698
# Coefficient of CBV #1: [0.66489541]
# Coefficient of CBV #2: [0.58827879]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007610713/kplr007610713-2012004120508_llc.fits...
#       -----
# reduced chi2: 1638.7180698596494
# rms: 97.89453612433529
# Coefficient of CBV #1: [-1.23084089]
# Coefficient of CBV #2: [0.32895411]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007610713/kplr007610713-2012088054726_llc.fits...
#       -----
# reduced chi2: 136.10137580146161
# rms: 25.61742278570776
# Coefficient of CBV #1: [0.30759327]
# Coefficient of CBV #2: [-0.14150598]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007610713/kplr007610713-2013131215648_llc.fits...
#       -----
# reduced chi2: 19.835529926117037
# rms: 9.061611816438264
# Coefficient of CBV #1: [0.04751925]
# Coefficient of CBV #2: [-0.05509988]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007610713/kplr007610713-2012277125453_llc.fits...
#       -----
# reduced chi2: 1153.635862479839
# rms: 89.73631787943712
# Coefficient of CBV #1: [-1.01541052]
# Coefficient of CBV #2: [-0.17940977]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007610713/kplr007610713-2012179063303_llc.fits...
#       -----
# reduced chi2: 823.9952109692324
# rms: 56.94671179388535
# Coefficient of CBV #1: [0.33330372]
# Coefficient of CBV #2: [0.67780446]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007610713/kplr007610713-2013011073258_llc.fits...
#       -----
# reduced chi2: 1227.3328947952332
# rms: 85.84016797442655
# Coefficient of CBV #1: [-1.11446291]
# Coefficient of CBV #2: [-2.86266361]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007610713/kplr007610713-2011271113734_llc.fits...
#       -----
# reduced chi2: 824.8966179724425
# rms: 74.79282125507838
# Coefficient of CBV #1: [0.52565444]
# Coefficient of CBV #2: [-0.69472968]
#       -----
# Writing output file ./light_curves_CBV_corr_2/007610713/kplr007610713-2013098041711_llc.fits...
#       -----
# reduced chi2: 102.52446383265448
# rms: 29.50150509177021
# Coefficient of CBV #1: [-0.02756034]
# Coefficient of CBV #2: [-0.20879749]
#       -----
# Writing output file ./light_curves_CBV_corr_2/008946433/kplr008946433-2012277125453_llc.fits...
#       -----
# reduced chi2: 931.2135480756757
# rms: 111.22509977798305
# Coefficient of CBV #1: [-0.75646267]
# Coefficient of CBV #2: [0.17787864]
#       -----
# Writing output file ./light_curves_CBV_corr_2/008946433/kplr008946433-2013011073258_llc.fits...
#       -----
# reduced chi2: 2355.4135708694007
# rms: 116.6130205025866
# Coefficient of CBV #1: [-0.99444731]
# Coefficient of CBV #2: [0.59937681]
#       -----
# Writing output file ./light_curves_CBV_corr_2/008946433/kplr008946433-2013098041711_llc.fits...
#       -----
# reduced chi2: 188.4114563863862
# rms: 20.796075406182666
# Coefficient of CBV #1: [-0.10094646]
# Coefficient of CBV #2: [-0.29327007]
#       -----
# Writing output file ./light_curves_CBV_corr_2/008946433/kplr008946433-2013131215648_llc.fits...
#       -----
# reduced chi2: 127.91056628192385
# rms: 35.10369259756327
# Coefficient of CBV #1: [-0.60857949]
# Coefficient of CBV #2: [-0.87939932]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009145961/kplr009145961-2013098041711_llc.fits...
#       -----
# reduced chi2: 60.94741303074948
# rms: 38.33852630774291
# Coefficient of CBV #1: [-0.60374929]
# Coefficient of CBV #2: [0.45851748]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009145961/kplr009145961-2013011073258_llc.fits...
#       -----
# reduced chi2: 501.3099583430664
# rms: 40.28847272037547
# Coefficient of CBV #1: [0.85391491]
# Coefficient of CBV #2: [-0.3310923]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009145961/kplr009145961-2012277125453_llc.fits...
#       -----
# reduced chi2: 1939.5441527915673
# rms: 90.4062745219477
# Coefficient of CBV #1: [2.08444414]
# Coefficient of CBV #2: [-0.07107911]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009145961/kplr009145961-2013131215648_llc.fits...
#       -----
# reduced chi2: 90.96794507761038
# rms: 16.190329848585126
# Coefficient of CBV #1: [0.38622502]
# Coefficient of CBV #2: [0.97199451]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009215110/kplr009215110-2013011073258_llc.fits...
#       -----
# reduced chi2: 46.548415604490444
# rms: 15.733334210491329
# Coefficient of CBV #1: [0.17080394]
# Coefficient of CBV #2: [1.26864273]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009215110/kplr009215110-2011271113734_llc.fits...
#       -----
# reduced chi2: 17.471905211060786
# rms: 9.46838592305804
# Coefficient of CBV #1: [-0.1640745]
# Coefficient of CBV #2: [-0.05095501]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009215110/kplr009215110-2013098041711_llc.fits...
#       -----
# reduced chi2: 22.21696566330136
# rms: 7.707636713108794
# Coefficient of CBV #1: [-0.23246675]
# Coefficient of CBV #2: [-0.04171903]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009215110/kplr009215110-2012277125453_llc.fits...
#       -----
# reduced chi2: 17.34362883098816
# rms: 9.387556289143424
# Coefficient of CBV #1: [-0.07666366]
# Coefficient of CBV #2: [0.0077369]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009215110/kplr009215110-2012179063303_llc.fits...
#       -----
# reduced chi2: 56.62634215770803
# rms: 22.78294128361528
# Coefficient of CBV #1: [0.38733509]
# Coefficient of CBV #2: [-0.41529139]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009215110/kplr009215110-2012088054726_llc.fits...
#       -----
# reduced chi2: 510.58293342802244
# rms: 37.31559568444315
# Coefficient of CBV #1: [1.13763406]
# Coefficient of CBV #2: [0.37513533]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009215110/kplr009215110-2012004120508_llc.fits...
#       -----
# reduced chi2: 149.0512302158284
# rms: 27.891993979469998
# Coefficient of CBV #1: [0.61436417]
# Coefficient of CBV #2: [-0.32021711]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009215110/kplr009215110-2013131215648_llc.fits...
#       -----
# reduced chi2: 114.78584676985899
# rms: 32.36613333954568
# Coefficient of CBV #1: [0.5189441]
# Coefficient of CBV #2: [0.18396124]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009650712/kplr009650712-2011271113734_llc.fits...
#       -----
# reduced chi2: 20299.313903982493
# rms: 401.0841288766687
# Coefficient of CBV #1: [-1.24914559]
# Coefficient of CBV #2: [1.89208926]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009650712/kplr009650712-2013098041711_llc.fits...
#       -----
# reduced chi2: 10883.498921266002
# rms: 275.2232127725426
# Coefficient of CBV #1: [-0.41534897]
# Coefficient of CBV #2: [-1.99798691]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009650712/kplr009650712-2013011073258_llc.fits...
#       -----
# reduced chi2: 56208.142014432146
# rms: 694.9584218605122
# Coefficient of CBV #1: [-4.51839174]
# Coefficient of CBV #2: [-1.06675609]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009650712/kplr009650712-2012179063303_llc.fits...
#       -----
# reduced chi2: 2057.5818055752557
# rms: 111.10700870067916
# Coefficient of CBV #1: [0.47892769]
# Coefficient of CBV #2: [0.52353479]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009650712/kplr009650712-2012277125453_llc.fits...
#       -----
# reduced chi2: 7288.734465678058
# rms: 218.79173943087926
# Coefficient of CBV #1: [-0.85089001]
# Coefficient of CBV #2: [-1.11986553]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009650712/kplr009650712-2013131215648_llc.fits...
#       -----
# reduced chi2: 3789.7650739751675
# rms: 145.76404226733823
# Coefficient of CBV #1: [-0.90734373]
# Coefficient of CBV #2: [2.66300991]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009650712/kplr009650712-2012004120508_llc.fits...
#       -----
# reduced chi2: 10112.031721088495
# rms: 297.1740025223752
# Coefficient of CBV #1: [-1.56518171]
# Coefficient of CBV #2: [0.74435926]
#       -----
# Writing output file ./light_curves_CBV_corr_2/009650712/kplr009650712-2012088054726_llc.fits...
#       -----
# reduced chi2: 19394.10051741575
# rms: 379.39409130517583
# Coefficient of CBV #1: [-2.19416886]
# Coefficient of CBV #2: [-1.19784495]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010645722/kplr010645722-2012088054726_llc.fits...
#       -----
# reduced chi2: 174.65097701330964
# rms: 24.595790386869645
# Coefficient of CBV #1: [-0.27104844]
# Coefficient of CBV #2: [-0.02370623]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010645722/kplr010645722-2012004120508_llc.fits...
#       -----
# reduced chi2: 686.0942514559881
# rms: 58.93899808549977
# Coefficient of CBV #1: [-1.38807893]
# Coefficient of CBV #2: [0.02490109]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010645722/kplr010645722-2013131215648_llc.fits...
#       -----
# reduced chi2: 101.77420345873661
# rms: 18.79873631075448
# Coefficient of CBV #1: [-0.36566649]
# Coefficient of CBV #2: [-0.28727805]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010645722/kplr010645722-2013011073258_llc.fits...
#       -----
# reduced chi2: 581.7036401167509
# rms: 61.942235146558474
# Coefficient of CBV #1: [-0.99535874]
# Coefficient of CBV #2: [-0.72217428]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010645722/kplr010645722-2013098041711_llc.fits...
#       -----
# reduced chi2: 706.821147593806
# rms: 36.805719305488246
# Coefficient of CBV #1: [-1.41948757]
# Coefficient of CBV #2: [0.15917295]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010645722/kplr010645722-2011271113734_llc.fits...
#       -----
# reduced chi2: 189.23581026867873
# rms: 33.64248966823826
# Coefficient of CBV #1: [-0.62718469]
# Coefficient of CBV #2: [0.28665463]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010645722/kplr010645722-2012277125453_llc.fits...
#       -----
# reduced chi2: 62.83643137648315
# rms: 19.51054431920787
# Coefficient of CBV #1: [0.10393974]
# Coefficient of CBV #2: [-0.27745548]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010645722/kplr010645722-2012179063303_llc.fits...
#       -----
# reduced chi2: 1769.7187287055679
# rms: 93.16911515332703
# Coefficient of CBV #1: [1.18227066]
# Coefficient of CBV #2: [-1.68779961]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010798894/kplr010798894-2013098041711_llc.fits...
#       -----
# reduced chi2: 103.22227333829869
# rms: 17.361059644085888
# Coefficient of CBV #1: [0.08215963]
# Coefficient of CBV #2: [-0.32704519]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010798894/kplr010798894-2013011073258_llc.fits...
#       -----
# reduced chi2: 623.6133033343976
# rms: 51.65553294882858
# Coefficient of CBV #1: [0.14754432]
# Coefficient of CBV #2: [1.55709293]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010798894/kplr010798894-2013131215648_llc.fits...
#       -----
# reduced chi2: 680.2244580682496
# rms: 54.426343269409806
# Coefficient of CBV #1: [-0.86020056]
# Coefficient of CBV #2: [0.29200249]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010841941/kplr010841941-2012277125453_llc.fits...
#       -----
# reduced chi2: 7325.305857835678
# rms: 153.05472570607157
# Coefficient of CBV #1: [5.73300164]
# Coefficient of CBV #2: [-0.97631757]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010841941/kplr010841941-2012179063303_llc.fits...
#       -----
# reduced chi2: 337.1704969285951
# rms: 46.38058285049659
# Coefficient of CBV #1: [-1.10392015]
# Coefficient of CBV #2: [-0.33665177]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010841941/kplr010841941-2013098041711_llc.fits...
#       -----
# reduced chi2: 294.2390548040997
# rms: 31.73620265350816
# Coefficient of CBV #1: [-1.22467044]
# Coefficient of CBV #2: [0.15098229]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010841941/kplr010841941-2013011073258_llc.fits...
#       -----
# reduced chi2: 876.9377369763586
# rms: 76.54304493622551
# Coefficient of CBV #1: [-1.84712295]
# Coefficient of CBV #2: [-0.64541854]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010841941/kplr010841941-2013131215648_llc.fits...
#       -----
# reduced chi2: 56.42689689654591
# rms: 19.152179760747604
# Coefficient of CBV #1: [-0.2567834]
# Coefficient of CBV #2: [0.11219449]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010841941/kplr010841941-2012004120508_llc.fits...
#       -----
# reduced chi2: 204.51629318456946
# rms: 36.89616270165854
# Coefficient of CBV #1: [-0.8739919]
# Coefficient of CBV #2: [0.43468125]
#       -----
# Writing output file ./light_curves_CBV_corr_2/010841941/kplr010841941-2012088054726_llc.fits...
#       -----
# reduced chi2: 503.14198360751385
# rms: 50.12712003158263
# Coefficient of CBV #1: [-1.2638278]
# Coefficient of CBV #2: [-0.3828542]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011413175/kplr011413175-2013131215648_llc.fits...
#       -----
# reduced chi2: 69.96237153058772
# rms: 15.31604464816471
# Coefficient of CBV #1: [0.09336574]
# Coefficient of CBV #2: [-0.18823095]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011413175/kplr011413175-2013098041711_llc.fits...
#       -----
# reduced chi2: 130.3035339669839
# rms: 30.07320564171022
# Coefficient of CBV #1: [-0.29779649]
# Coefficient of CBV #2: [-0.54470044]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011413175/kplr011413175-2013011073258_llc.fits...
#       -----
# reduced chi2: 97.75279933703038
# rms: 24.817582073464475
# Coefficient of CBV #1: [-0.28535138]
# Coefficient of CBV #2: [0.08178966]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011606854/kplr011606854-2012004120508_llc.fits...
#       -----
# reduced chi2: 3178.7706918601707
# rms: 76.66190363305799
# Coefficient of CBV #1: [-4.08315848]
# Coefficient of CBV #2: [-0.599248]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011606854/kplr011606854-2011177032512_llc.fits...
#       -----
# reduced chi2: 119.59587315423387
# rms: 25.50298392289468
# Coefficient of CBV #1: [-0.78463626]
# Coefficient of CBV #2: [0.9013662]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011606854/kplr011606854-2012088054726_llc.fits...
#       -----
# reduced chi2: 70.98205573386586
# rms: 15.844602932234688
# Coefficient of CBV #1: [-0.42834198]
# Coefficient of CBV #2: [0.48528394]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011606854/kplr011606854-2013131215648_llc.fits...
#       -----
# reduced chi2: 79.82908026839361
# rms: 24.241390456609803
# Coefficient of CBV #1: [-1.73521339]
# Coefficient of CBV #2: [1.42124839]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011606854/kplr011606854-2011073133259_llc.fits...
#       -----
# reduced chi2: 747.9011622790466
# rms: 70.55719837569832
# Coefficient of CBV #1: [2.33228219]
# Coefficient of CBV #2: [-0.362331]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011606854/kplr011606854-2010355172524_llc.fits...
#       -----
# reduced chi2: 596.4896256912305
# rms: 32.82735365964276
# Coefficient of CBV #1: [-1.84067391]
# Coefficient of CBV #2: [0.19727189]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011606854/kplr011606854-2012277125453_llc.fits...
#       -----
# reduced chi2: 3408.7722049545746
# rms: 105.28857253798877
# Coefficient of CBV #1: [-5.07930083]
# Coefficient of CBV #2: [0.21055656]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011606854/kplr011606854-2012179063303_llc.fits...
#       -----
# reduced chi2: 186.23991351768188
# rms: 31.905400993729316
# Coefficient of CBV #1: [-1.23019086]
# Coefficient of CBV #2: [-0.48368685]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011606854/kplr011606854-2010265121752_llc.fits...
#       -----
# reduced chi2: 2282.72285719989
# rms: 86.21757272575206
# Coefficient of CBV #1: [4.10377462]
# Coefficient of CBV #2: [-0.67001075]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011606854/kplr011606854-2013011073258_llc.fits...
#       -----
# reduced chi2: 1729.3964903409467
# rms: 55.92255991473432
# Coefficient of CBV #1: [-2.8695948]
# Coefficient of CBV #2: [0.22245068]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011606854/kplr011606854-2013098041711_llc.fits...
#       -----
# reduced chi2: 398.6655474985306
# rms: 36.88276738422383
# Coefficient of CBV #1: [0.88681781]
# Coefficient of CBV #2: [-1.50922891]
#       -----
# Writing output file ./light_curves_CBV_corr_2/011606854/kplr011606854-2011271113734_llc.fits...
#       -----
# reduced chi2: 6807.652562361359
# rms: 108.04979025841386
# Coefficient of CBV #1: [7.2976152]
# Coefficient of CBV #2: [-0.10590833]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012010193/kplr012010193-2013131215648_llc.fits...
#       -----
# reduced chi2: 2.6738751493907595
# rms: 4.065618020609928
# Coefficient of CBV #1: [0.04068874]
# Coefficient of CBV #2: [0.0183937]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012010193/kplr012010193-2013098041711_llc.fits...
#       -----
# reduced chi2: 97.00849500160467
# rms: 19.019947468607175
# Coefficient of CBV #1: [0.70364456]
# Coefficient of CBV #2: [-0.56192419]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012010193/kplr012010193-2013011073258_llc.fits...
#       -----
# reduced chi2: 299.5003744212944
# rms: 39.101665618367186
# Coefficient of CBV #1: [-1.35367369]
# Coefficient of CBV #2: [-0.15770977]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012010193/kplr012010193-2012277125453_llc.fits...
#       -----
# reduced chi2: 3474.521168800609
# rms: 162.09780863613642
# Coefficient of CBV #1: [2.48033489]
# Coefficient of CBV #2: [-0.04975479]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012158940/kplr012158940-2011177032512_llc.fits...
#       -----
# reduced chi2: 14353.904704738943
# rms: 428.35736447378366
# Coefficient of CBV #1: [0.68714085]
# Coefficient of CBV #2: [-2.93460627]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012158940/kplr012158940-2012004120508_llc.fits...
#       -----
# reduced chi2: 2518.0855438000226
# rms: 124.03233348307505
# Coefficient of CBV #1: [1.03726598]
# Coefficient of CBV #2: [-0.29970039]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012158940/kplr012158940-2012088054726_llc.fits...
#       -----
# reduced chi2: 15476.49712551987
# rms: 354.5742197978014
# Coefficient of CBV #1: [-2.46953063]
# Coefficient of CBV #2: [-0.63555061]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012158940/kplr012158940-2013131215648_llc.fits...
#       -----
# reduced chi2: 113.4671339668845
# rms: 39.39913933309726
# Coefficient of CBV #1: [0.37578144]
# Coefficient of CBV #2: [-0.54652809]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012158940/kplr012158940-2013011073258_llc.fits...
#       -----
# reduced chi2: 55007.59303062547
# rms: 702.943754281401
# Coefficient of CBV #1: [-3.67105328]
# Coefficient of CBV #2: [0.59183354]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012158940/kplr012158940-2011271113734_llc.fits...
#       -----
# reduced chi2: 11486.398917518432
# rms: 355.26136602165553
# Coefficient of CBV #1: [-1.73275049]
# Coefficient of CBV #2: [2.03131532]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012158940/kplr012158940-2013098041711_llc.fits...
#       -----
# reduced chi2: 15229.880800027975
# rms: 198.40498359983619
# Coefficient of CBV #1: [2.48924923]
# Coefficient of CBV #2: [2.19793027]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012158940/kplr012158940-2012179063303_llc.fits...
#       -----
# reduced chi2: 11477.498325567018
# rms: 386.3714996167865
# Coefficient of CBV #1: [1.22206603]
# Coefficient of CBV #2: [2.13745228]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012158940/kplr012158940-2012277125453_llc.fits...
#       -----
# reduced chi2: 23983.02009579342
# rms: 531.0771599605937
# Coefficient of CBV #1: [-3.10943957]
# Coefficient of CBV #2: [-0.33610602]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012158940/kplr012158940-2011073133259_llc.fits...
#       -----
# reduced chi2: 102.57871120136578
# rms: 28.614435233426892
# Coefficient of CBV #1: [0.18699375]
# Coefficient of CBV #2: [-0.01059633]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012158940/kplr012158940-2010355172524_llc.fits...
#       -----
# reduced chi2: 1357.4202723529327
# rms: 91.50894555279471
# Coefficient of CBV #1: [0.55547223]
# Coefficient of CBV #2: [-0.41777143]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012158940/kplr012158940-2010265121752_llc.fits...
#       -----
# reduced chi2: 2392.8353423635417
# rms: 162.28428716314593
# Coefficient of CBV #1: [1.09480137]
# Coefficient of CBV #2: [-0.02627359]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012208602/kplr012208602-2010355172524_llc.fits...
#       -----
# reduced chi2: 72.38204059178085
# rms: 18.956654340256758
# Coefficient of CBV #1: [1.43367585]
# Coefficient of CBV #2: [0.10242355]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012208602/kplr012208602-2011073133259_llc.fits...
#       -----
# reduced chi2: 2.35927836770669
# rms: 3.649276494478264
# Coefficient of CBV #1: [0.16602973]
# Coefficient of CBV #2: [0.02640751]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012208602/kplr012208602-2012277125453_llc.fits...
#       -----
# reduced chi2: 31.8373947946573
# rms: 7.441463262299088
# Coefficient of CBV #1: [0.59059083]
# Coefficient of CBV #2: [0.74892727]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012208602/kplr012208602-2012179063303_llc.fits...
#       -----
# reduced chi2: 4.080986305218814
# rms: 5.419681201086248
# Coefficient of CBV #1: [-0.30825724]
# Coefficient of CBV #2: [0.20038819]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012208602/kplr012208602-2010265121752_llc.fits...
#       -----
# reduced chi2: 312.42313952994704
# rms: 23.343628268395054
# Coefficient of CBV #1: [2.74084273]
# Coefficient of CBV #2: [0.63069823]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012208602/kplr012208602-2013011073258_llc.fits...
#       -----
# reduced chi2: 42.2612534949279
# rms: 14.54850187361303
# Coefficient of CBV #1: [-0.0782095]
# Coefficient of CBV #2: [-1.19367217]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012208602/kplr012208602-2011271113734_llc.fits...
#       -----
# reduced chi2: 282.81177685740465
# rms: 22.007608831161797
# Coefficient of CBV #1: [-3.27002656]
# Coefficient of CBV #2: [-0.6623943]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012208602/kplr012208602-2013098041711_llc.fits...
#       -----
# reduced chi2: 103.79328525330936
# rms: 24.170565439691924
# Coefficient of CBV #1: [1.58906973]
# Coefficient of CBV #2: [1.13926798]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012208602/kplr012208602-2012004120508_llc.fits...
#       -----
# reduced chi2: 106.95697999777694
# rms: 22.95926481453965
# Coefficient of CBV #1: [-1.96571472]
# Coefficient of CBV #2: [0.20193555]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012208602/kplr012208602-2011177032512_llc.fits...
#       -----
# reduced chi2: 133.24160829391033
# rms: 30.919570661507766
# Coefficient of CBV #1: [-2.61996707]
# Coefficient of CBV #2: [0.60289332]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012208602/kplr012208602-2012088054726_llc.fits...
#       -----
# reduced chi2: 43.82097227312585
# rms: 13.999137381644172
# Coefficient of CBV #1: [1.01087323]
# Coefficient of CBV #2: [-0.33920837]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012208602/kplr012208602-2013131215648_llc.fits...
#       -----
# reduced chi2: 1.7277914788554232
# rms: 3.585580800448276
# Coefficient of CBV #1: [-0.24306389]
# Coefficient of CBV #2: [0.30033655]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012401487/kplr012401487-2013131215648_llc.fits...
#       -----
# reduced chi2: 39.45036138444061
# rms: 45.064507786316504
# Coefficient of CBV #1: [-1.02535226]
# Coefficient of CBV #2: [1.56643828]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012401487/kplr012401487-2013011073258_llc.fits...
#       -----
# reduced chi2: 582.6781213326867
# rms: 152.2253732101781
# Coefficient of CBV #1: [1.04810853]
# Coefficient of CBV #2: [-0.08251558]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012401487/kplr012401487-2013098041711_llc.fits...
#       -----
# reduced chi2: 58.26500364724897
# rms: 60.64833554941462
# Coefficient of CBV #1: [-0.15268438]
# Coefficient of CBV #2: [0.15850285]
#       -----
# Writing output file ./light_curves_CBV_corr_2/012401487/kplr012401487-2012277125453_llc.fits...
#       -----
# reduced chi2: 268.95900754042526
# rms: 115.2629026307326
# Coefficient of CBV #1: [0.48480699]
# Coefficient of CBV #2: [-0.66321016]
#       -----

# %%
kepcotrend??

# %%
object_index = 0
print(names[object_index])
dfs = fetch_light_curve(object_index)
# Out:
# 002694186

# %%
fig,ax = plt.subplots(figsize=(15,7))
for df in dfs:

    mask = df['MASK'].values
    vals = df['CBVSAP_FLUX'] - df['CBVSAP_FLUX'].mean()
    ax.errorbar(df['TIME'],vals,df['SAP_FLUX_ERR'],fmt='.')
    ax.plot(df['TIME'],vals.min()+df['THERMAL_RECOVERY']*(vals.max()-vals.min()),color='k')

    ax.plot(df['TIME'][mask],vals[mask]-100,color='k')
ax.set_xlim(600,1600)
# Out:
# (600.0, 1600.0)

# %%
object_index = 1
print(names[object_index])
dfs = fetch_light_curve(object_index)

fig,ax = plt.subplots(figsize=(15,7))
for df in dfs:

    mask = df['MASK'].values
    vals = df['CBVSAP_FLUX'] - df['CBVSAP_FLUX'].mean()
    ax.errorbar(df['TIME'],vals,df['SAP_FLUX_ERR'],fmt='.')
    ax.plot(df['TIME'],vals.min()+df['THERMAL_RECOVERY']*(vals.max()-vals.min()),color='k')

    ax.plot(df['TIME'][mask],vals[mask]-100,color='k')
# Out:
# 002837332

# %%
object_index = 3
print(names[object_index])
dfs = fetch_light_curve(object_index)
# Out:
# 005781475

# %%
fig,ax = plt.subplots(3,1,figsize=(15,15))
for df in dfs:

    mask = df['MASK'].values
    ax[0].errorbar(df['TIME'],df['SAP_FLUX'],df['SAP_FLUX_ERR'],fmt='.')
    ax[0].plot(df['TIME'],df['SAP_FLUX'].min()+~df['THERMAL_RECOVERY']*(df['SAP_FLUX'].max()-df['SAP_FLUX'].min()),color='k')
    ax[1].errorbar(df['TIME'],df['CBVSAP_FLUX'],df['SAP_FLUX_ERR'],fmt='.')
    ax[1].plot(df['TIME'],df['CBVSAP_FLUX'].min()+df['THERMAL_RECOVERY']*(df['CBVSAP_FLUX'].max()-df['CBVSAP_FLUX'].min()),color='k')

    ax[2].errorbar(df['TIME'],df['PDCSAP_FLUX'],df['PDCSAP_FLUX_ERR'],fmt='.')
    ax[2].plot(df['TIME'],df['PDCSAP_FLUX'].min()+df['THERMAL_RECOVERY']*(df['PDCSAP_FLUX'].max()-df['PDCSAP_FLUX'].min()),color='k')

# %%
df = pd.concat(fetch_light_curve(3,listbv='1 2'))

# %%
df.iloc[6681:]
# Out:
#              TIME  TIMECORR  CADENCENO    SAP_FLUX  SAP_FLUX_ERR     SAP_BKG  \
# 1924  1412.800767  0.001013      63810  796.722595      1.665892  334.594330
# 1925  1412.821199  0.001012      63811         NaN           NaN         NaN
# 1926  1412.841632  0.001011      63812         NaN           NaN         NaN
# 1927  1412.862065  0.001010      63813         NaN           NaN         NaN
# 1928  1412.882497  0.001009      63814         NaN           NaN         NaN
# ...           ...       ...        ...         ...           ...         ...
# 1551  1590.919902  0.000485      72527  985.707581      1.763889  368.182861
# 1552  1590.940337  0.000485      72528  984.884277      1.763720  368.294220
# 1553  1590.960771  0.000486      72529  986.081360      1.763927  367.359772
# 1554  1590.981206  0.000487      72530  984.956909      1.763643  367.998962
# 1555  1591.001640  0.000488      72531  979.963318      1.762939  367.879639
#
#       SAP_BKG_ERR  PDCSAP_FLUX  PDCSAP_FLUX_ERR  SAP_QUALITY  ...  MOM_CENTR2  \
# 1924     0.108948  1383.785767         2.763637            0  ...  406.609696
# 1925          NaN          NaN              NaN        32800  ...         NaN
# 1926          NaN          NaN              NaN        32768  ...         NaN
# 1927          NaN          NaN              NaN        32768  ...         NaN
# 1928          NaN          NaN              NaN        32768  ...         NaN
# ...           ...          ...              ...          ...  ...         ...
# 1551     0.112325  1335.899048         2.484381            0  ...  410.654771
# 1552     0.112478  1333.123535         2.480670            0  ...  410.653354
# 1553     0.112393  1329.122925         2.480510            0  ...  410.652725
# 1554     0.112371  1323.740112         2.444988            0  ...  410.651299
# 1555     0.112428  1324.451782         2.469604            0  ...  410.654047
#
#       MOM_CENTR2_ERR   POS_CORR1   POS_CORR2  CBVSAP_MODL  CBVSAP_FLUX  \
# 1924        0.002868   -0.001088    0.010278     0.026618   819.509462
# 1925             NaN         NaN         NaN          NaN          NaN
# 1926             NaN -929.777771 -407.634552          NaN          NaN
# 1927             NaN -929.777771 -407.634552          NaN          NaN
# 1928             NaN -929.777771 -407.634552          NaN          NaN
# ...              ...         ...         ...          ...          ...
# 1551        0.002824    0.010539   -0.004506    -0.030915   956.785295
# 1552        0.002839    0.010704   -0.004693    -0.031293   955.608387
# 1553        0.002840    0.010670   -0.004530    -0.030998   957.081263
# 1554        0.002832    0.011810   -0.005066    -0.032800   954.271025
# 1555        0.002829    0.010733   -0.004674    -0.031892   950.126956
#
#       THERMAL_RECOVERY   MASK  FILENUM  QUARTER
# 1924              True   True        2       15
# 1925              True  False        2       15
# 1926             False  False        2       15
# 1927             False  False        2       15
# 1928             False  False        2       15
# ...                ...    ...      ...      ...
# 1551              True   True        3       17
# 1552              True   True        3       17
# 1553              True   True        3       17
# 1554              True   True        3       17
# 1555              True   True        3       17
#
# [8615 rows x 26 columns]

# %%
filepath = './reduced_light_curves/temp_1/'
Path(filepath).mkdir(parents=True,exist_ok=True)

# %%
!

# %%
filepath = './reduced_light_curves/temp_2/'
Path(filepath).mkdir(parents=True,exist_ok=True)

# %%
for object_index,name in enumerate(names):
    df = pd.concat(fetch_light_curve(object_index,listbv='1 2'))
    q = df[['TIME','CADENCENO','PDCSAP_FLUX','PDCSAP_FLUX_ERR','CBVSAP_FLUX','SAP_FLUX','SAP_FLUX_ERR','SAP_QUALITY','THERMAL_RECOVERY','MASK','QUARTER']]
    q.columns = ['time','cadenceno','flux','flux err','cbv flux','raw flux','raw flux err','quality','thermal recovery','mask','quarter']
    q.to_csv(filepath+str(name)+'.csv')
